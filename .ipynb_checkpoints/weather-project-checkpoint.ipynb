# %%
# Check Git is installed
# !git --version

# Install jupyterlab-git
# !pip install jupyterlab-git

# Configure Git identity
# !git config --global user.name "Your Name"
# !git config --global user.email "you@example.com"
# Out:
# git version 2.51.0.windows.1
# Requirement already satisfied: jupyterlab-git in c:\users\user\anaconda3\lib\site-packages (0.52.0)
# Requirement already satisfied: jupyter-server<3,>=2.0.1 in c:\users\user\anaconda3\lib\site-packages (from jupyterlab-git) (2.16.0)
# Requirement already satisfied: nbdime~=4.0.1 in c:\users\user\anaconda3\lib\site-packages (from jupyterlab-git) (4.0.4)
# Requirement already satisfied: nbformat in c:\users\user\anaconda3\lib\site-packages (from jupyterlab-git) (5.10.4)
# Requirement already satisfied: packaging in c:\users\user\anaconda3\lib\site-packages (from jupyterlab-git) (25.0)
# Requirement already satisfied: pexpect in c:\users\user\anaconda3\lib\site-packages (from jupyterlab-git) (4.9.0)
# Requirement already satisfied: traitlets~=5.0 in c:\users\user\anaconda3\lib\site-packages (from jupyterlab-git) (5.14.3)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (4.10.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (21.3.0)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (3.1.6)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (5.8.1)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (7.16.6)
# Requirement already satisfied: overrides>=5.0 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (0.21.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (2.0.15)
# Requirement already satisfied: pyzmq>=24 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (27.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (0.18.1)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (6.5.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (1.8.0)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from nbdime~=4.0.1->jupyterlab-git) (0.4.6)
# Requirement already satisfied: gitpython!=2.1.4,!=2.1.5,!=2.1.6 in c:\users\user\anaconda3\lib\site-packages (from nbdime~=4.0.1->jupyterlab-git) (3.1.45)
# Requirement already satisfied: pygments in c:\users\user\anaconda3\lib\site-packages (from nbdime~=4.0.1->jupyterlab-git) (2.19.2)
# Requirement already satisfied: requests in c:\users\user\anaconda3\lib\site-packages (from nbdime~=4.0.1->jupyterlab-git) (2.32.5)
# Requirement already satisfied: idna>=2.8 in c:\users\user\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (3.11)
# Requirement already satisfied: sniffio>=1.1 in c:\users\user\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\user\anaconda3\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.0.1->jupyterlab-git) (25.1.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\user\anaconda3\lib\site-packages (from gitpython!=2.1.4,!=2.1.5,!=2.1.6->nbdime~=4.0.1->jupyterlab-git) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\user\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=2.1.4,!=2.1.5,!=2.1.6->nbdime~=4.0.1->jupyterlab-git) (4.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\lib\site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.0.1->jupyterlab-git) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\anaconda3\lib\site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\user\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.0.1->jupyterlab-git) (4.5.0)
# Requirement already satisfied: pywin32>=300 in c:\users\user\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.0.1->jupyterlab-git) (311)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\user\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (4.25.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\user\anaconda3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (3.2.1)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\user\anaconda3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (6.0.3)
# Requirement already satisfied: referencing in c:\users\user\anaconda3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (0.37.0)
# Requirement already satisfied: rfc3339-validator in c:\users\user\anaconda3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\user\anaconda3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (0.1.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\user\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\user\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (2025.9.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\user\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (0.28.0)
# Requirement already satisfied: fqdn in c:\users\user\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\user\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\user\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in c:\users\user\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (1.1.0)
# Requirement already satisfied: uri-template in c:\users\user\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\user\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\user\anaconda3\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (6.3.0)
# Requirement already satisfied: defusedxml in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (3.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\user\anaconda3\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\user\anaconda3\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\user\anaconda3\lib\site-packages (from nbformat->jupyterlab-git) (2.21.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=7.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (1.17.0)
# Requirement already satisfied: lark>=1.2.2 in c:\users\user\anaconda3\lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (1.3.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.0.1->jupyterlab-git) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\user\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.0.1->jupyterlab-git) (2.23)
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\user\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (4.15.0)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\user\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (1.4.0)
# Requirement already satisfied: tzdata in c:\users\user\anaconda3\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (2025.2)
# Requirement already satisfied: ptyprocess>=0.5 in c:\users\user\anaconda3\lib\site-packages (from pexpect->jupyterlab-git) (0.7.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests->nbdime~=4.0.1->jupyterlab-git) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests->nbdime~=4.0.1->jupyterlab-git) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests->nbdime~=4.0.1->jupyterlab-git) (2026.1.4)
